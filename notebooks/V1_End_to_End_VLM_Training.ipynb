# %% [markdown]
# # Notebook cũ đã ngừng sử dụng
#
# Dùng [Kaggle_V1_Training.ipynb](Kaggle_V1_Training.ipynb) và [hướng dẫn](../docs/README_KAGGLE.md). Toàn bộ training nằm trong module `.py`. Không chạy vòng lặp cũ vì masking và đường đọc ảnh đã thay đổi.
